# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset('tips')

# Pair plot with regression lines
sns.pairplot(tips, hue='sex', kind='reg', height=2.5)
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# linear regression
# logistic regression
# k means clusturing
# mean absolute error
# root mean squared error
# R-squared error
# confusion matrix
# accuray , precision , recall
# preprocessing
# histogram
